# %% [markdown]
# ## Загрузка всех необходимых пакетов

# %%
## Базовые пакеты для работы с датасетом
import pyreadstat
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoCV

from statsmodels.multivariate.factor import Factor

import scipy.stats as stats
from scipy.stats import mannwhitneyu as U

import seaborn as sns

# %% [markdown]
# ## Чтение данных

# %%
# Чтение данных
df, meta = pyreadstat.read_sav(r"C:\Users\79118\OneDrive\Рабочий стол\00РЦ\Архивы проектов [подготовленные]\Мониторинг здоровья 2024\МЗ_универсанты_перекодир_сон.sav", apply_value_formats=True)
df.shape
# Out:
# (2083, 512)

# %% [markdown]
# ## Необходимые для работы функции

# %%
# Функция для рчной перекодировки данных

def recode_spss_variable(series, meta, var_name):
    if var_name in meta.variable_value_labels:
        label_map = {v: k for k, v in meta.variable_value_labels[var_name].items()}
        return series.map(label_map).astype('Int64')
    return series

# %%
def fillna_custom(df, columns_to_fill):
    for var in columns_to_fill:
        if pd.api.types.is_numeric_dtype(df[var]): 
            df[var] = df[var].astype('float64')
            df[var] = df[var].fillna(df[var].median()).astype('float64')
        elif isinstance(df[var].dtype, pd.CategoricalDtype):
            df[var]  = df[var].cat.add_categories(['MISSING'])
            df[var]  = df[var].fillna('MISSING')
        elif pd.api.types.is_timedelta64_dtype(df[var]):
            mode_value = df[var].mode()[0]
            df[var] =df[var].fillna(mode_value)
    return df

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Работа с типом данных

# %%
# Список числовых и порядковых переменных, которые используются при моделировании

num_comp = [
    'q012',
    'q021', 
    'q022_001', 'q022_002', 'q022_003', 'q022_004', 'q022_005',
     'q023_001', 'q023_002', 'q023_003', 'q023_004',
    'q025_001', 'q025_002', 'q025_003', 'q025_004', 'q025_005', 'q025_006', 'q025_007',
    'q030_001', 'q030_002', 'q030_003', 'q030_004',
    'q031_001', 'q031_002', 'q031_003', 'q031_004', 'q031_005', 'q031_006', 'q031_007', 'q031_008', 'q031_009', 'q031_010', 'q031_011',
   
    'q038',
    'q041', 'q042', 'q043', 'q044',
    'q046_001', 'q046_002',
    'q052',

    # 'q057_001', 'q057_002', 'q057_003', 'q057_004', 'q057_005', 'q057_006', 'q057_007', 'q057_89', 'q057_010', 'q057_011', 'q057_012', 'q057_013', 'q057_014', 'q057_008', 'q057_009', 'q057_015',
    
     'q059_001', 'q059_002', 'q059_003', 'q059_004', 'q059_005', 'q059_006', 'q059_007', 'q059_008', 'q059_009', 'q059_010',
    'q061', 
    'q062_001', 'q063_001', 'q063_002', 'q063_003', 'q063_004', 'q063_005', 'q063_006', 'q063_007',
    'q067_001', 'q067_002', 'q067_003', 'q067_004', 'q067_005', 'q067_006', 'q067_007', 'q067_008', 'q067_009', 'q067_010',
    'q078',
    'q080',
   
    'q088_001', 'q088_002', 'q088_003', 'q088_004', 'q088_005', 'q088_006', 'q088_007', 
    'q089',
    'q091', 'q092',
    'q094',
    'q095_001', 'q095_002', 'q095_003', 'q095_004', 'q095_005', 'q095_006', 'q095_007', 'q095_008', 'q095_009',
    'q098',
    'q106_001', 'q106_002', 'q106_003', 'q106_004', 'q106_005', 'q106_006', 'q106_007',
    'q107_001', 'q107_002', 'q107_003', 'q107_004', 'q107_005', 'q107_006', 'q107_007',
    'q108_001', 'q108_002', 'q108_003', 'q108_004', 'q108_005', 'q108_006', 'q108_007',
    'q112', 
    'q119', 'q120', 
    'q128', 'q129',
   
    'q131_006', 'q131_007', 'q131_008',
    'q134_001', 'q134_002', 'q134_003', 'q134_004', 'q134_005',
    'q139_001', 'q139_002', 'q139_003', 'q139_004', 'q139_005', 'q139_006', 'q139_007', 'q139_008', 'q139_009', 'q139_010', 'q139_011', 'q139_012',
    'q126',
    'q135_001', 'q135_002', 'q135_003',
    'q138',
] 

other_cor = [
    'q004', 'q028',
    'q040_001', 'q040_002', 'q040_003', 'q040_004',
    'q079', 'q090', 'q096', 'q103',
    'q118_01', 'q118_02', 'q133',
    'PHQ_9', 'RES', 'SAMEF', 'SLEEP', 'OSSS', 'STRESS', 'alko']
# список переменных

# %%
# Переменные, которые не будут напрямую участвовать в моделировании. Являются частью психологических методик

phq = [
    'q032_001', 'q032_002', 'q032_003', 'q032_004', 'q032_005', 'q032_006', 'q032_007', 'q032_008', 'q032_009',
]

res = [
     'q033_001', 'q033_002', 'q033_003', 'q033_004', 'q033_005', 'q033_006'
]

self = [
   'q033_007', 'q033_008', 'q033_009', 'q033_010', 'q033_011', 'q033_012', 'q033_013', 'q033_014'
]

oslo = ['q034', 'q036', 'q037']

stress = [
    'q131_001', 'q131_002', 'q131_003', 'q131_004', 'q131_005'
]

AUDIT = [
'q081', 'q082', 'q083', 'q084', 'q085', 'q086', 'q087'
]

HIV = [
    'q076_001', 'q076_002', 'q076_003', 'q076_004', 'q076_005'
]

sleep_ind = [
     'q121', 
    'q122_001', 'q122_002', 'q122_003', 'q122_004',
    'q123', 'q124', 'q125'
]

# %%
# Переменные, которые содержат служебную информацию

sec_col = [
    'q001',
    'ANSWERID',
 'ANSWERDATE',
 'ANSWERTAKENTIME',
 'ANSWERSOURCENAME',
 'ANSWERSOURCELABEL',
 'IPHASH',
 'UAHASH',
   'q020', 'q117_001', 'q117_002', 'q117_003', 'q117_004', 'q117_005', 'q117_006', 'q117_007', 'q117_008',
    'q146', 'i80', 'i85_87', 'i82_84', 'PHQ_Log'
]

# Переменные с ответами на открытые вопросы, не пригодны для количественной обработки
open = [
'q029', 'q058', 'q105', 'q113', 'q113_comment', 'q114', 'q114_comment', 'q115', 'q115_comment', 'q116', 'q116_comment', 'q118', 'q118_comment', 'q127', 'q140', 'q141', 'q141_comment', 'q142', 'q143', 'q147'
]

# %%
times = ['q113_01', 'q113_02', 
         'q114_01', 'q114_02',
         'q115_01', 'q115_02', 
         'q116_01', 'q116_02']

# for col in times:
#     df[col] = pd.to_timedelta(df[col].str.replace(':', 'h') + 'm',  errors='coerce')


# sec1 = df['q113_01'].dt.total_seconds()
# sec2 = df['q113_02'].dt.total_seconds()
# diff = np.where(sec2 < sec1, sec2 + 86400, sec2)  # Добавляем 24 часа (86400 сек) если время "перескочило"
# avg_seconds = (sec1 + diff) / 2
# df['average_time_to_bed_week'] = pd.to_timedelta(avg_seconds % 86400, unit='s')

# sec1_weekend = df['q114_01'].dt.total_seconds()
# sec2_weekend = df['q114_02'].dt.total_seconds()
# diff_weekend = np.where(sec2_weekend < sec1_weekend, sec2_weekend + 86400, sec2_weekend)  # Добавляем 24 часа (86400 сек) если время "перескочило"
# avg_seconds_weekend = (sec1_weekend + diff_weekend) / 2
# df['average_time_to_bed_weekend'] = pd.to_timedelta(avg_seconds_weekend % 86400, unit='s')


# df['average_time_wake_week'] = (df['q115_01'] + df['q115_02'])/2
# df['average_time_wake_weekend'] = (df['q116_01'] + df['q116_02'])/2

# df['average_time_sleep_dur'] = (df['q118_01'] + df['q118_02'])/2

# %%
# Категориальные переменные

good_cat = [
     'q024_001', 'q024_002', 'q024_003', 'q024_004', 'q024_005', 'q024_006', 'q024_007', 'q024_008', 'q024_009', 'q024_010', 'q024_011',
    'q026_001', 'q026_002', 'q026_003', 'q026_004', 
    'q027_001', 'q027_002', 'q027_003', 'q027_004', 'q027_005', 'q027_006',
    'q035_001', 'q035_002', 'q035_003', 'q035_004', 'q035_005', 'q035_006', 'q035_007', 'q035_008', 'q035_009', 'q035_010', 'q035_011', 'q035_012', 'q035_013',
    'q039_001', 'q039_002', 'q039_003', 'q039_004', 'q039_005', 'q039_006', 'q039_007', 'q039_008', 'q039_009', 'q039_010', 'q039_011', 'q039_012', 'q039_013', 'q039_014', 'q039_015', 'q039_016',
    'q051_001', 'q051_002', 'q051_003', 'q051_004', 'q051_005', 'q051_006', 'q051_nothing',
     'q055_001', 'q055_002', 'q055_003', 'q055_004', 'q055_005', 'q055_006', 'q055_007', 'q055_008', 'q055_009', 'q055_nothing',
    'q056_001', 'q056_002', 'q056_003', 'q056_004', 'q056_005', 'q056_006', 'q056_007', 'q056_008', 
    'q057_001', 'q057_002', 'q057_003', 'q057_004', 'q057_005', 'q057_006', 'q057_007', 'q057_89', 'q057_010', 'q057_011', 'q057_012', 'q057_013', 'q057_014', 'q057_008', 'q057_009', 'q057_015', 
    'q064_001', 'q064_002', 'q064_003', 'q064_004', 'q064_005', 'q064_006', 'q064_007', 'q064_008',
    'q069_001', 'q069_002',
     'q070', 'q071_001', 'q072', 'q073', 'q074', 'q075', 
    # 'q076_001', 'q076_002', 'q076_003', 'q076_004', 'q076_005', 
    'q077_001', 'q077_002', 'q077_003', 'q077_004', 'q077_005', 'q077_006', 'q077_007', 'q077_008', 'q077_009',
    'q093_001', 'q093_002', 'q093_003', 'q093_004', 'q093_005', 'q093_006', 'q093_007', 'q093_008', 'q093_009',
     'q097_001', 'q097_002', 'q097_003', 'q097_004', 'q097_005', 'q097_006', 'q097_007', 'q097_89', 'q097_010', 'q097_008', 'q097_009', 
    'q099_001', 'q099_002', 'q099_003', 'q099_004', 'q099_005', 'q099_006', 'q099_007', 'q099_008', 'q099_009',
    'q109_001', 'q109_002', 'q109_003', 'q109_004', 'q109_005', 'q109_006', 'q109_007', 'q109_008', 'q109_009',
    'q137_001', 'q137_002', 'q137_003', 'q137_004', 'q137_005', 'q137_006', 'q137_007', 'q137_008', 'q137_009', 'q137_010', 'q137_011', 'q137_012', 'q137_013', 'q137_014', 'q137_015', 'q137_016', 'q137_017', 'q137_018',
]

good_cat_for_one_hot = [
   'q002', 'q003', 'q005', 'q006', 'q007',
    'q008', 'q009', 'q010', 'q011', 
    'q013', 'q014', 'q015', 'q016', 'q017',
    'q018', 
    # 'q019',
    'q045', 'q047', 'q048', 'q049', 
    'q050',
    'q053', 'q054', 
    'q060', 
    'q065', 'q066', 'q068', 
    # 'q081', 
    'q100', 'q101', 'q102', 'q104', 
    'q111', 
     'q130', 
    'q132', 
    'q136',
    'q144', 
    'q145', 
    'Q40cat', 
    'PHQ_9cat',
    'RES_cat', 
    'SAMEF_cat', 
    'OSSScat', 
    'STRESScat', 
    'AUDIT', 
   'SF', 'Ind'
]

# %% [markdown]
# ### Обработка данных, чистка данных

# %%
for var in num_comp:
    df[var] = recode_spss_variable(df[var], meta, var)

for var in sleep_ind:
    df[var] = recode_spss_variable(df[var], meta, var)

other_columns = df.filter(like='_other').columns.tolist()
unable_columns = df.filter(like='_unable').columns.tolist()

df = df.drop(sec_col, axis = 1)
df = df.drop(times, axis = 1)
df = df.drop(other_columns, axis = 1)
df = df.drop(unable_columns, axis = 1)

df_no_methods = df.drop(phq + res + self + stress + oslo + sleep_ind + AUDIT + HIV, axis = 1)

df_no_methods_wo_open = df_no_methods.drop(open, axis = 1)

# %%
# Итоговое число переменных после удаления лишних
df_no_methods_wo_open.shape
# Out:
# (2083, 389)

# %% [markdown]
# ### Обработка данных, работа с категориальными переменными

# %%
for var in good_cat:
    df_no_methods_wo_open[var] = df_no_methods_wo_open[var].astype('category')
    df_no_methods_wo_open[var] = df_no_methods_wo_open[var].cat.codes

for var in good_cat_for_one_hot:
    df_no_methods_wo_open[var] = df_no_methods_wo_open[var].astype('category')
    df_no_methods_wo_open[var] = df_no_methods_wo_open[var].cat.codes

# %%
df_no_methods_wo_open_encoded = pd.get_dummies(df_no_methods_wo_open, columns=good_cat_for_one_hot + good_cat, drop_first=True)

# %%
# Итоговое число переменных с дамми-переменными
df_no_methods_wo_open_encoded.shape
# Out:
# (2083, 676)

# %% [markdown]
# ## Корреляционный анализ

# %%
# Оставляем только количественные и порядковые переменные, пригодные для корреляционного анализа
df_no_methods_wo_open_encoded_cor = df_no_methods_wo_open_encoded[num_comp + other_cor]

# %%
# Строим корреляционную матрицу в отношении SQI - индекса качества сна
correlation_matrix = df_no_methods_wo_open_encoded_cor.corr()
target_corr = correlation_matrix['SLEEP'].abs().sort_values(ascending=False)

# %%
# Первые 20 переменных, коррелятов с целевой
target_corr.head(20)
# Out:
# SLEEP       1.000000
# PHQ_9       0.577363
# q119        0.547451
# q120        0.514327
# q038        0.424622
# q031_007    0.397805
# RES         0.381283
# q112        0.372477
# q030_003    0.352596
# q031_001    0.341396
# q044        0.339613
# SAMEF       0.312571
# q031_011    0.312258
# q030_001    0.307763
# q031_009    0.300365
# q030_002    0.297339
# q041        0.294564
# q131_007    0.285983
# q031_008    0.283928
# q106_006    0.283123
# Name: SLEEP, dtype: float64

# %% [markdown]
# ## Работа с пропущенными значениями

# %% [markdown]
# ### Удаления тех переменных, в которых очень много пропусков. Замена пропусков

# %%
threshold = 0.5 * len(df_no_methods_wo_open_encoded)  # 50% от размера выборки

# Вычисление количества пропусков в каждом столбце
missing_counts = df_no_methods_wo_open_encoded.isnull().sum()
columns_to_drop = missing_counts[missing_counts > threshold].index

print(columns_to_drop)
df_no_methods_wo_open_encoded_clean = df_no_methods_wo_open_encoded.drop(columns=columns_to_drop)
# Out:
# Index(['q019', 'q052', 'q061', 'q062_001', 'q063_001', 'q063_002', 'q063_003',
#        'q063_004', 'q063_005', 'q063_006', 'q063_007', 'q067_001', 'q067_002',
#        'q067_003', 'q067_004', 'q067_005', 'q067_006', 'q067_007', 'q067_008',
#        'q067_009', 'q067_010', 'q095_001', 'q095_002', 'q095_003', 'q095_004',
#        'q095_005', 'q095_006', 'q095_007', 'q095_008', 'q095_009', 'q096',
#        'q103', 'q106_001', 'q106_002', 'q106_003', 'q106_004', 'q106_005',
#        'q106_006', 'q106_007', 'q133', 'q134_001', 'q134_002', 'q134_003',
#        'q134_004', 'q134_005', 'q135_001', 'q135_002', 'q135_003', 'Q40',
#        'Q40cat2'],
#       dtype='object')

# %%
# Количество переменных для регрессионного и факторного анализаанализа
df_no_methods_wo_open_encoded_clean.shape
# Out:
# (2083, 626)

# %%
missing_in_clean = df_no_methods_wo_open_encoded_clean.isnull().sum()
missing_in_clean_only = missing_in_clean[missing_in_clean > 0]
columns_to_fill = missing_in_clean_only.index
df_no_methods_wo_open_encoded_clean = fillna_custom(df_no_methods_wo_open_encoded_clean, columns_to_fill)

# %%
# Проверка замены пропусков
cols = df_no_methods_wo_open_encoded_clean.isna().sum()
cols = cols[cols > 0]
len(cols)
# Out:
# 0

# %% [markdown]
# ## Отбор переменных для регрессионного и факторного анализа. Переменные и факторы, влияющие на качество сна

# %%
y = df_no_methods_wo_open_encoded_clean['SLEEP']
X_data = df_no_methods_wo_open_encoded_clean.drop(['SLEEP'], axis = 1)

# %% [markdown]
# ### Автоматический выбор переменных

# %%
# Проверка переменных на корректный тип
for column in X_data.columns:
    try:
        # Пробуем преобразовать столбец в float
        pd.to_numeric(X_data[column], errors='raise')  # 'raise' вызовет ошибку при проблемах
        print(f"✅ {column} — преобразуется в float без ошибок")
    except ValueError as e:
        print(f"❌ {column} — ошибка: {e}")
# Out:
# ✅ q004 — преобразуется в float без ошибок
# ✅ q012 — преобразуется в float без ошибок
# ✅ q021 — преобразуется в float без ошибок
# ✅ q022_001 — преобразуется в float без ошибок
# ✅ q022_002 — преобразуется в float без ошибок
# ✅ q022_003 — преобразуется в float без ошибок
# ✅ q022_004 — преобразуется в float без ошибок
# ✅ q022_005 — преобразуется в float без ошибок
# ✅ q023_001 — преобразуется в float без ошибок
# ✅ q023_002 — преобразуется в float без ошибок
# ✅ q023_003 — преобразуется в float без ошибок
# ✅ q023_004 — преобразуется в float без ошибок
# ✅ q025_001 — преобразуется в float без ошибок
# ✅ q025_002 — преобразуется в float без ошибок
# ✅ q025_003 — преобразуется в float без ошибок
# ✅ q025_004 — преобразуется в float без ошибок
# ✅ q025_005 — преобразуется в float без ошибок
# ✅ q025_006 — преобразуется в float без ошибок
# ✅ q025_007 — преобразуется в float без ошибок
# ✅ q028 — преобразуется в float без ошибок
# ✅ q030_001 — преобразуется в float без ошибок
# ✅ q030_002 — преобразуется в float без ошибок
# ✅ q030_003 — преобразуется в float без ошибок
# ✅ q030_004 — преобразуется в float без ошибок
# ✅ q031_001 — преобразуется в float без ошибок
# ✅ q031_002 — преобразуется в float без ошибок
# ✅ q031_003 — преобразуется в float без ошибок
# ✅ q031_004 — преобразуется в float без ошибок
# ✅ q031_005 — преобразуется в float без ошибок
# ✅ q031_006 — преобразуется в float без ошибок
# ✅ q031_007 — преобразуется в float без ошибок
# ✅ q031_008 — преобразуется в float без ошибок
# ✅ q031_009 — преобразуется в float без ошибок
# ✅ q031_010 — преобразуется в float без ошибок
# ✅ q031_011 — преобразуется в float без ошибок
# ✅ q038 — преобразуется в float без ошибок
# ✅ q040_001 — преобразуется в float без ошибок
# ✅ q040_002 — преобразуется в float без ошибок
# ✅ q040_003 — преобразуется в float без ошибок
# ✅ q040_004 — преобразуется в float без ошибок
# ✅ q041 — преобразуется в float без ошибок
# ✅ q042 — преобразуется в float без ошибок
# ✅ q043 — преобразуется в float без ошибок
# ✅ q044 — преобразуется в float без ошибок
# ✅ q046_001 — преобразуется в float без ошибок
# ✅ q046_002 — преобразуется в float без ошибок
# ✅ q059_001 — преобразуется в float без ошибок
# ✅ q059_002 — преобразуется в float без ошибок
# ✅ q059_003 — преобразуется в float без ошибок
# ✅ q059_004 — преобразуется в float без ошибок
# ✅ q059_005 — преобразуется в float без ошибок
# ✅ q059_006 — преобразуется в float без ошибок
# ✅ q059_007 — преобразуется в float без ошибок
# ✅ q059_008 — преобразуется в float без ошибок
# ✅ q059_009 — преобразуется в float без ошибок
# ✅ q059_010 — преобразуется в float без ошибок
# ✅ q078 — преобразуется в float без ошибок
# ✅ q079 — преобразуется в float без ошибок
# ✅ q080 — преобразуется в float без ошибок
# ✅ q088_001 — преобразуется в float без ошибок
# ✅ q088_002 — преобразуется в float без ошибок
# ✅ q088_003 — преобразуется в float без ошибок
# ✅ q088_004 — преобразуется в float без ошибок
# ✅ q088_005 — преобразуется в float без ошибок
# ✅ q088_006 — преобразуется в float без ошибок
# ✅ q088_007 — преобразуется в float без ошибок
# ✅ q089 — преобразуется в float без ошибок
# ✅ q090 — преобразуется в float без ошибок
# ✅ q091 — преобразуется в float без ошибок
# ✅ q092 — преобразуется в float без ошибок
# ✅ q094 — преобразуется в float без ошибок
# ✅ q098 — преобразуется в float без ошибок
# ✅ q107_001 — преобразуется в float без ошибок
# ✅ q107_002 — преобразуется в float без ошибок
# ✅ q107_003 — преобразуется в float без ошибок
# ✅ q107_004 — преобразуется в float без ошибок
# ✅ q107_005 — преобразуется в float без ошибок
# ✅ q107_006 — преобразуется в float без ошибок
# ✅ q107_007 — преобразуется в float без ошибок
# ✅ q108_001 — преобразуется в float без ошибок
# ✅ q108_002 — преобразуется в float без ошибок
# ✅ q108_003 — преобразуется в float без ошибок
# ✅ q108_004 — преобразуется в float без ошибок
# ✅ q108_005 — преобразуется в float без ошибок
# ✅ q108_006 — преобразуется в float без ошибок
# ✅ q108_007 — преобразуется в float без ошибок
# ✅ q110 — преобразуется в float без ошибок
# ✅ q112 — преобразуется в float без ошибок
# ✅ q118_01 — преобразуется в float без ошибок
# ✅ q118_02 — преобразуется в float без ошибок
# ✅ q119 — преобразуется в float без ошибок
# ✅ q120 — преобразуется в float без ошибок
# ✅ q126 — преобразуется в float без ошибок
# ✅ q128 — преобразуется в float без ошибок
# ✅ q129 — преобразуется в float без ошибок
# ✅ q131_006 — преобразуется в float без ошибок
# ✅ q131_007 — преобразуется в float без ошибок
# ✅ q131_008 — преобразуется в float без ошибок
# ✅ q138 — преобразуется в float без ошибок
# ✅ q139_001 — преобразуется в float без ошибок
# ✅ q139_002 — преобразуется в float без ошибок
# ✅ q139_003 — преобразуется в float без ошибок
# ✅ q139_004 — преобразуется в float без ошибок
# ✅ q139_005 — преобразуется в float без ошибок
# ✅ q139_006 — преобразуется в float без ошибок
# ✅ q139_007 — преобразуется в float без ошибок
# ✅ q139_008 — преобразуется в float без ошибок
# ✅ q139_009 — преобразуется в float без ошибок
# ✅ q139_010 — преобразуется в float без ошибок
# ✅ q139_011 — преобразуется в float без ошибок
# ✅ q139_012 — преобразуется в float без ошибок
# ✅ q141_01 — преобразуется в float без ошибок
# ✅ q141_02 — преобразуется в float без ошибок
# ✅ q142_01 — преобразуется в float без ошибок
# ✅ q142_02 — преобразуется в float без ошибок
# ✅ PHQ_9 — преобразуется в float без ошибок
# ✅ RES — преобразуется в float без ошибок
# ✅ SAMEF — преобразуется в float без ошибок
# ✅ OSSS — преобразуется в float без ошибок
# ✅ STRESS — преобразуется в float без ошибок
# ✅ alko — преобразуется в float без ошибок
# ✅ q002_0 — преобразуется в float без ошибок
# ✅ q002_1 — преобразуется в float без ошибок
# ✅ q002_2 — преобразуется в float без ошибок
# ✅ q003_0 — преобразуется в float без ошибок
# ✅ q003_1 — преобразуется в float без ошибок
# ✅ q005_0 — преобразуется в float без ошибок
# ✅ q005_1 — преобразуется в float без ошибок
# ✅ q005_2 — преобразуется в float без ошибок
# ✅ q005_3 — преобразуется в float без ошибок
# ✅ q005_4 — преобразуется в float без ошибок
# ✅ q006_0 — преобразуется в float без ошибок
# ✅ q006_1 — преобразуется в float без ошибок
# ✅ q007_0 — преобразуется в float без ошибок
# ✅ q007_1 — преобразуется в float без ошибок
# ✅ q008_0 — преобразуется в float без ошибок
# ✅ q008_1 — преобразуется в float без ошибок
# ✅ q008_2 — преобразуется в float без ошибок
# ✅ q008_3 — преобразуется в float без ошибок
# ✅ q008_4 — преобразуется в float без ошибок
# ✅ q008_5 — преобразуется в float без ошибок
# ✅ q009_0 — преобразуется в float без ошибок
# ✅ q009_1 — преобразуется в float без ошибок
# ✅ q009_2 — преобразуется в float без ошибок
# ✅ q009_3 — преобразуется в float без ошибок
# ✅ q009_4 — преобразуется в float без ошибок
# ✅ q009_5 — преобразуется в float без ошибок
# ✅ q009_6 — преобразуется в float без ошибок
# ✅ q009_7 — преобразуется в float без ошибок
# ✅ q009_8 — преобразуется в float без ошибок
# ✅ q010_0 — преобразуется в float без ошибок
# ✅ q010_1 — преобразуется в float без ошибок
# ✅ q010_2 — преобразуется в float без ошибок
# ✅ q010_3 — преобразуется в float без ошибок
# ✅ q010_4 — преобразуется в float без ошибок
# ✅ q010_5 — преобразуется в float без ошибок
# ✅ q010_6 — преобразуется в float без ошибок
# ✅ q010_7 — преобразуется в float без ошибок
# ✅ q011_0 — преобразуется в float без ошибок
# ✅ q013_0 — преобразуется в float без ошибок
# ✅ q013_1 — преобразуется в float без ошибок
# ✅ q014_0 — преобразуется в float без ошибок
# ✅ q014_1 — преобразуется в float без ошибок
# ✅ q014_2 — преобразуется в float без ошибок
# ✅ q014_3 — преобразуется в float без ошибок
# ✅ q014_4 — преобразуется в float без ошибок
# ✅ q014_5 — преобразуется в float без ошибок
# ✅ q014_6 — преобразуется в float без ошибок
# ✅ q014_7 — преобразуется в float без ошибок
# ✅ q014_8 — преобразуется в float без ошибок
# ✅ q014_9 — преобразуется в float без ошибок
# ✅ q014_10 — преобразуется в float без ошибок
# ✅ q014_11 — преобразуется в float без ошибок
# ✅ q014_12 — преобразуется в float без ошибок
# ✅ q014_13 — преобразуется в float без ошибок
# ✅ q014_14 — преобразуется в float без ошибок
# ✅ q014_15 — преобразуется в float без ошибок
# ✅ q014_16 — преобразуется в float без ошибок
# ✅ q014_17 — преобразуется в float без ошибок
# ✅ q014_18 — преобразуется в float без ошибок
# ✅ q014_19 — преобразуется в float без ошибок
# ✅ q014_20 — преобразуется в float без ошибок
# ✅ q014_21 — преобразуется в float без ошибок
# ✅ q014_22 — преобразуется в float без ошибок
# ✅ q014_23 — преобразуется в float без ошибок
# ✅ q014_24 — преобразуется в float без ошибок
# ✅ q014_25 — преобразуется в float без ошибок
# ✅ q014_26 — преобразуется в float без ошибок
# ✅ q014_27 — преобразуется в float без ошибок
# ✅ q015_0 — преобразуется в float без ошибок
# ✅ q015_1 — преобразуется в float без ошибок
# ✅ q015_2 — преобразуется в float без ошибок
# ✅ q015_3 — преобразуется в float без ошибок
# ✅ q015_4 — преобразуется в float без ошибок
# ✅ q015_5 — преобразуется в float без ошибок
# ✅ q016_0 — преобразуется в float без ошибок
# ✅ q016_1 — преобразуется в float без ошибок
# ✅ q017_0 — преобразуется в float без ошибок
# ✅ q017_1 — преобразуется в float без ошибок
# ✅ q017_2 — преобразуется в float без ошибок
# ✅ q017_3 — преобразуется в float без ошибок
# ✅ q017_4 — преобразуется в float без ошибок
# ✅ q017_5 — преобразуется в float без ошибок
# ✅ q017_6 — преобразуется в float без ошибок
# ✅ q018_0 — преобразуется в float без ошибок
# ✅ q018_1 — преобразуется в float без ошибок
# ✅ q018_2 — преобразуется в float без ошибок
# ✅ q018_3 — преобразуется в float без ошибок
# ✅ q045_0 — преобразуется в float без ошибок
# ✅ q045_1 — преобразуется в float без ошибок
# ✅ q045_2 — преобразуется в float без ошибок
# ✅ q045_3 — преобразуется в float без ошибок
# ✅ q045_4 — преобразуется в float без ошибок
# ✅ q045_5 — преобразуется в float без ошибок
# ✅ q045_6 — преобразуется в float без ошибок
# ✅ q047_0 — преобразуется в float без ошибок
# ✅ q047_1 — преобразуется в float без ошибок
# ✅ q047_2 — преобразуется в float без ошибок
# ✅ q048_0 — преобразуется в float без ошибок
# ✅ q048_1 — преобразуется в float без ошибок
# ✅ q048_2 — преобразуется в float без ошибок
# ✅ q049_0 — преобразуется в float без ошибок
# ✅ q049_1 — преобразуется в float без ошибок
# ✅ q050_0 — преобразуется в float без ошибок
# ✅ q050_1 — преобразуется в float без ошибок
# ✅ q053_0 — преобразуется в float без ошибок
# ✅ q053_1 — преобразуется в float без ошибок
# ✅ q054_0 — преобразуется в float без ошибок
# ✅ q054_1 — преобразуется в float без ошибок
# ✅ q054_2 — преобразуется в float без ошибок
# ✅ q054_3 — преобразуется в float без ошибок
# ✅ q060_0 — преобразуется в float без ошибок
# ✅ q060_1 — преобразуется в float без ошибок
# ✅ q060_2 — преобразуется в float без ошибок
# ✅ q060_3 — преобразуется в float без ошибок
# ✅ q060_4 — преобразуется в float без ошибок
# ✅ q065_0 — преобразуется в float без ошибок
# ✅ q065_1 — преобразуется в float без ошибок
# ✅ q065_2 — преобразуется в float без ошибок
# ✅ q066_0 — преобразуется в float без ошибок
# ✅ q066_1 — преобразуется в float без ошибок
# ✅ q066_2 — преобразуется в float без ошибок
# ✅ q068_0 — преобразуется в float без ошибок
# ✅ q068_1 — преобразуется в float без ошибок
# ✅ q068_2 — преобразуется в float без ошибок
# ✅ q068_3 — преобразуется в float без ошибок
# ✅ q068_4 — преобразуется в float без ошибок
# ✅ q068_5 — преобразуется в float без ошибок
# ✅ q068_6 — преобразуется в float без ошибок
# ✅ q068_7 — преобразуется в float без ошибок
# ✅ q100_0 — преобразуется в float без ошибок
# ✅ q100_1 — преобразуется в float без ошибок
# ✅ q100_2 — преобразуется в float без ошибок
# ✅ q101_0 — преобразуется в float без ошибок
# ✅ q101_1 — преобразуется в float без ошибок
# ✅ q101_2 — преобразуется в float без ошибок
# ✅ q101_3 — преобразуется в float без ошибок
# ✅ q101_4 — преобразуется в float без ошибок
# ✅ q101_5 — преобразуется в float без ошибок
# ✅ q102_0 — преобразуется в float без ошибок
# ✅ q102_1 — преобразуется в float без ошибок
# ✅ q102_2 — преобразуется в float без ошибок
# ✅ q102_3 — преобразуется в float без ошибок
# ✅ q104_0 — преобразуется в float без ошибок
# ✅ q104_1 — преобразуется в float без ошибок
# ✅ q111_0 — преобразуется в float без ошибок
# ✅ q111_1 — преобразуется в float без ошибок
# ✅ q111_2 — преобразуется в float без ошибок
# ✅ q111_3 — преобразуется в float без ошибок
# ✅ q111_4 — преобразуется в float без ошибок
# ✅ q130_0 — преобразуется в float без ошибок
# ✅ q130_1 — преобразуется в float без ошибок
# ✅ q132_0 — преобразуется в float без ошибок
# ✅ q132_1 — преобразуется в float без ошибок
# ✅ q136_0 — преобразуется в float без ошибок
# ✅ q136_1 — преобразуется в float без ошибок
# ✅ q144_0 — преобразуется в float без ошибок
# ✅ q144_1 — преобразуется в float без ошибок
# ✅ q144_2 — преобразуется в float без ошибок
# ✅ q144_3 — преобразуется в float без ошибок
# ✅ q144_4 — преобразуется в float без ошибок
# ✅ q144_5 — преобразуется в float без ошибок
# ✅ q144_6 — преобразуется в float без ошибок
# ✅ q144_7 — преобразуется в float без ошибок
# ✅ q145_0 — преобразуется в float без ошибок
# ✅ q145_1 — преобразуется в float без ошибок
# ✅ q145_2 — преобразуется в float без ошибок
# ✅ q145_3 — преобразуется в float без ошибок
# ✅ q145_4 — преобразуется в float без ошибок
# ✅ Q40cat_0 — преобразуется в float без ошибок
# ✅ Q40cat_1 — преобразуется в float без ошибок
# ✅ Q40cat_2 — преобразуется в float без ошибок
# ✅ Q40cat_3 — преобразуется в float без ошибок
# ✅ Q40cat_4 — преобразуется в float без ошибок
# ✅ Q40cat_5 — преобразуется в float без ошибок
# ✅ Q40cat_6 — преобразуется в float без ошибок
# ✅ Q40cat_7 — преобразуется в float без ошибок
# ✅ Q40cat_8 — преобразуется в float без ошибок
# ✅ Q40cat_9 — преобразуется в float без ошибок
# ✅ Q40cat_10 — преобразуется в float без ошибок
# ✅ Q40cat_11 — преобразуется в float без ошибок
# ✅ Q40cat_12 — преобразуется в float без ошибок
# ✅ PHQ_9cat_0 — преобразуется в float без ошибок
# ✅ PHQ_9cat_1 — преобразуется в float без ошибок
# ✅ PHQ_9cat_2 — преобразуется в float без ошибок
# ✅ PHQ_9cat_3 — преобразуется в float без ошибок
# ✅ PHQ_9cat_4 — преобразуется в float без ошибок
# ✅ RES_cat_0 — преобразуется в float без ошибок
# ✅ RES_cat_1 — преобразуется в float без ошибок
# ✅ RES_cat_2 — преобразуется в float без ошибок
# ✅ SAMEF_cat_0 — преобразуется в float без ошибок
# ✅ SAMEF_cat_1 — преобразуется в float без ошибок
# ✅ SAMEF_cat_2 — преобразуется в float без ошибок
# ✅ SAMEF_cat_3 — преобразуется в float без ошибок
# ✅ SAMEF_cat_4 — преобразуется в float без ошибок
# ✅ OSSScat_0 — преобразуется в float без ошибок
# ✅ OSSScat_1 — преобразуется в float без ошибок
# ✅ OSSScat_2 — преобразуется в float без ошибок
# ✅ STRESScat_0 — преобразуется в float без ошибок
# ✅ STRESScat_1 — преобразуется в float без ошибок
# ✅ STRESScat_2 — преобразуется в float без ошибок
# ✅ AUDIT_0 — преобразуется в float без ошибок
# ✅ AUDIT_1 — преобразуется в float без ошибок
# ✅ SF_0 — преобразуется в float без ошибок
# ✅ SF_1 — преобразуется в float без ошибок
# ✅ SF_2 — преобразуется в float без ошибок
# ✅ SF_3 — преобразуется в float без ошибок
# ✅ SF_4 — преобразуется в float без ошибок
# ✅ SF_5 — преобразуется в float без ошибок
# ✅ Ind_0 — преобразуется в float без ошибок
# ✅ Ind_1 — преобразуется в float без ошибок
# ✅ q024_001_1 — преобразуется в float без ошибок
# ✅ q024_002_1 — преобразуется в float без ошибок
# ✅ q024_003_1 — преобразуется в float без ошибок
# ✅ q024_004_1 — преобразуется в float без ошибок
# ✅ q024_005_1 — преобразуется в float без ошибок
# ✅ q024_006_1 — преобразуется в float без ошибок
# ✅ q024_007_1 — преобразуется в float без ошибок
# ✅ q024_008_1 — преобразуется в float без ошибок
# ✅ q024_009_1 — преобразуется в float без ошибок
# ✅ q024_010_1 — преобразуется в float без ошибок
# ✅ q024_011_1 — преобразуется в float без ошибок
# ✅ q026_001_0 — преобразуется в float без ошибок
# ✅ q026_001_1 — преобразуется в float без ошибок
# ✅ q026_002_1 — преобразуется в float без ошибок
# ✅ q026_003_0 — преобразуется в float без ошибок
# ✅ q026_003_1 — преобразуется в float без ошибок
# ✅ q026_004_0 — преобразуется в float без ошибок
# ✅ q026_004_1 — преобразуется в float без ошибок
# ✅ q027_001_1 — преобразуется в float без ошибок
# ✅ q027_002_1 — преобразуется в float без ошибок
# ✅ q027_003_0 — преобразуется в float без ошибок
# ✅ q027_003_1 — преобразуется в float без ошибок
# ✅ q027_004_0 — преобразуется в float без ошибок
# ✅ q027_004_1 — преобразуется в float без ошибок
# ✅ q027_005_0 — преобразуется в float без ошибок
# ✅ q027_005_1 — преобразуется в float без ошибок
# ✅ q027_006_0 — преобразуется в float без ошибок
# ✅ q027_006_1 — преобразуется в float без ошибок
# ✅ q035_001_0 — преобразуется в float без ошибок
# ✅ q035_001_1 — преобразуется в float без ошибок
# ✅ q035_002_0 — преобразуется в float без ошибок
# ✅ q035_002_1 — преобразуется в float без ошибок
# ✅ q035_003_0 — преобразуется в float без ошибок
# ✅ q035_003_1 — преобразуется в float без ошибок
# ✅ q035_004_0 — преобразуется в float без ошибок
# ✅ q035_004_1 — преобразуется в float без ошибок
# ✅ q035_005_0 — преобразуется в float без ошибок
# ✅ q035_005_1 — преобразуется в float без ошибок
# ✅ q035_006_0 — преобразуется в float без ошибок
# ✅ q035_006_1 — преобразуется в float без ошибок
# ✅ q035_007_0 — преобразуется в float без ошибок
# ✅ q035_007_1 — преобразуется в float без ошибок
# ✅ q035_008_0 — преобразуется в float без ошибок
# ✅ q035_008_1 — преобразуется в float без ошибок
# ✅ q035_009_0 — преобразуется в float без ошибок
# ✅ q035_009_1 — преобразуется в float без ошибок
# ✅ q035_010_0 — преобразуется в float без ошибок
# ✅ q035_010_1 — преобразуется в float без ошибок
# ✅ q035_011_0 — преобразуется в float без ошибок
# ✅ q035_011_1 — преобразуется в float без ошибок
# ✅ q035_012_0 — преобразуется в float без ошибок
# ✅ q035_012_1 — преобразуется в float без ошибок
# ✅ q035_013_0 — преобразуется в float без ошибок
# ✅ q035_013_1 — преобразуется в float без ошибок
# ✅ q039_001_1 — преобразуется в float без ошибок
# ✅ q039_002_1 — преобразуется в float без ошибок
# ✅ q039_003_1 — преобразуется в float без ошибок
# ✅ q039_004_1 — преобразуется в float без ошибок
# ✅ q039_005_1 — преобразуется в float без ошибок
# ✅ q039_006_1 — преобразуется в float без ошибок
# ✅ q039_007_1 — преобразуется в float без ошибок
# ✅ q039_008_1 — преобразуется в float без ошибок
# ✅ q039_009_1 — преобразуется в float без ошибок
# ✅ q039_010_1 — преобразуется в float без ошибок
# ✅ q039_011_1 — преобразуется в float без ошибок
# ✅ q039_012_1 — преобразуется в float без ошибок
# ✅ q039_013_1 — преобразуется в float без ошибок
# ✅ q039_014_1 — преобразуется в float без ошибок
# ✅ q039_015_1 — преобразуется в float без ошибок
# ✅ q039_016_1 — преобразуется в float без ошибок
# ✅ q051_001_1 — преобразуется в float без ошибок
# ✅ q051_002_1 — преобразуется в float без ошибок
# ✅ q051_003_1 — преобразуется в float без ошибок
# ✅ q051_004_1 — преобразуется в float без ошибок
# ✅ q051_005_1 — преобразуется в float без ошибок
# ✅ q051_006_1 — преобразуется в float без ошибок
# ✅ q051_nothing_1 — преобразуется в float без ошибок
# ✅ q055_001_0 — преобразуется в float без ошибок
# ✅ q055_001_1 — преобразуется в float без ошибок
# ✅ q055_002_0 — преобразуется в float без ошибок
# ✅ q055_002_1 — преобразуется в float без ошибок
# ✅ q055_003_0 — преобразуется в float без ошибок
# ✅ q055_003_1 — преобразуется в float без ошибок
# ✅ q055_004_0 — преобразуется в float без ошибок
# ✅ q055_004_1 — преобразуется в float без ошибок
# ✅ q055_005_0 — преобразуется в float без ошибок
# ✅ q055_005_1 — преобразуется в float без ошибок
# ✅ q055_006_0 — преобразуется в float без ошибок
# ✅ q055_006_1 — преобразуется в float без ошибок
# ✅ q055_007_0 — преобразуется в float без ошибок
# ✅ q055_007_1 — преобразуется в float без ошибок
# ✅ q055_008_0 — преобразуется в float без ошибок
# ✅ q055_008_1 — преобразуется в float без ошибок
# ✅ q055_009_0 — преобразуется в float без ошибок
# ✅ q055_009_1 — преобразуется в float без ошибок
# ✅ q055_nothing_0 — преобразуется в float без ошибок
# ✅ q055_nothing_1 — преобразуется в float без ошибок
# ✅ q056_001_0 — преобразуется в float без ошибок
# ✅ q056_001_1 — преобразуется в float без ошибок
# ✅ q056_002_0 — преобразуется в float без ошибок
# ✅ q056_002_1 — преобразуется в float без ошибок
# ✅ q056_003_0 — преобразуется в float без ошибок
# ✅ q056_003_1 — преобразуется в float без ошибок
# ✅ q056_004_0 — преобразуется в float без ошибок
# ✅ q056_004_1 — преобразуется в float без ошибок
# ✅ q056_005_0 — преобразуется в float без ошибок
# ✅ q056_005_1 — преобразуется в float без ошибок
# ✅ q056_006_0 — преобразуется в float без ошибок
# ✅ q056_006_1 — преобразуется в float без ошибок
# ✅ q056_007_0 — преобразуется в float без ошибок
# ✅ q056_007_1 — преобразуется в float без ошибок
# ✅ q056_008_0 — преобразуется в float без ошибок
# ✅ q056_008_1 — преобразуется в float без ошибок
# ✅ q057_001_0 — преобразуется в float без ошибок
# ✅ q057_001_1 — преобразуется в float без ошибок
# ✅ q057_002_0 — преобразуется в float без ошибок
# ✅ q057_002_1 — преобразуется в float без ошибок
# ✅ q057_003_0 — преобразуется в float без ошибок
# ✅ q057_003_1 — преобразуется в float без ошибок
# ✅ q057_004_0 — преобразуется в float без ошибок
# ✅ q057_004_1 — преобразуется в float без ошибок
# ✅ q057_005_0 — преобразуется в float без ошибок
# ✅ q057_005_1 — преобразуется в float без ошибок
# ✅ q057_006_0 — преобразуется в float без ошибок
# ✅ q057_006_1 — преобразуется в float без ошибок
# ✅ q057_007_0 — преобразуется в float без ошибок
# ✅ q057_007_1 — преобразуется в float без ошибок
# ✅ q057_89_0 — преобразуется в float без ошибок
# ✅ q057_89_1 — преобразуется в float без ошибок
# ✅ q057_010_0 — преобразуется в float без ошибок
# ✅ q057_010_1 — преобразуется в float без ошибок
# ✅ q057_011_0 — преобразуется в float без ошибок
# ✅ q057_011_1 — преобразуется в float без ошибок
# ✅ q057_012_0 — преобразуется в float без ошибок
# ✅ q057_012_1 — преобразуется в float без ошибок
# ✅ q057_013_0 — преобразуется в float без ошибок
# ✅ q057_013_1 — преобразуется в float без ошибок
# ✅ q057_014_0 — преобразуется в float без ошибок
# ✅ q057_014_1 — преобразуется в float без ошибок
# ✅ q057_008_0 — преобразуется в float без ошибок
# ✅ q057_008_1 — преобразуется в float без ошибок
# ✅ q057_009_0 — преобразуется в float без ошибок
# ✅ q057_009_1 — преобразуется в float без ошибок
# ✅ q057_015_0 — преобразуется в float без ошибок
# ✅ q057_015_1 — преобразуется в float без ошибок
# ✅ q064_001_0 — преобразуется в float без ошибок
# ✅ q064_001_1 — преобразуется в float без ошибок
# ✅ q064_001_2 — преобразуется в float без ошибок
# ✅ q064_002_0 — преобразуется в float без ошибок
# ✅ q064_002_1 — преобразуется в float без ошибок
# ✅ q064_002_2 — преобразуется в float без ошибок
# ✅ q064_003_0 — преобразуется в float без ошибок
# ✅ q064_003_1 — преобразуется в float без ошибок
# ✅ q064_003_2 — преобразуется в float без ошибок
# ✅ q064_004_0 — преобразуется в float без ошибок
# ✅ q064_004_1 — преобразуется в float без ошибок
# ✅ q064_004_2 — преобразуется в float без ошибок
# ✅ q064_005_0 — преобразуется в float без ошибок
# ✅ q064_005_1 — преобразуется в float без ошибок
# ✅ q064_005_2 — преобразуется в float без ошибок
# ✅ q064_006_0 — преобразуется в float без ошибок
# ✅ q064_006_1 — преобразуется в float без ошибок
# ✅ q064_006_2 — преобразуется в float без ошибок
# ✅ q064_007_0 — преобразуется в float без ошибок
# ✅ q064_007_1 — преобразуется в float без ошибок
# ✅ q064_007_2 — преобразуется в float без ошибок
# ✅ q064_008_0 — преобразуется в float без ошибок
# ✅ q064_008_1 — преобразуется в float без ошибок
# ✅ q064_008_2 — преобразуется в float без ошибок
# ✅ q069_001_0 — преобразуется в float без ошибок
# ✅ q069_001_1 — преобразуется в float без ошибок
# ✅ q069_001_2 — преобразуется в float без ошибок
# ✅ q069_002_0 — преобразуется в float без ошибок
# ✅ q069_002_1 — преобразуется в float без ошибок
# ✅ q069_002_2 — преобразуется в float без ошибок
# ✅ q070_0 — преобразуется в float без ошибок
# ✅ q070_1 — преобразуется в float без ошибок
# ✅ q070_2 — преобразуется в float без ошибок
# ✅ q070_3 — преобразуется в float без ошибок
# ✅ q071_001_0 — преобразуется в float без ошибок
# ✅ q071_001_1 — преобразуется в float без ошибок
# ✅ q071_001_2 — преобразуется в float без ошибок
# ✅ q071_001_3 — преобразуется в float без ошибок
# ✅ q071_001_4 — преобразуется в float без ошибок
# ✅ q072_0 — преобразуется в float без ошибок
# ✅ q072_1 — преобразуется в float без ошибок
# ✅ q073_0 — преобразуется в float без ошибок
# ✅ q073_1 — преобразуется в float без ошибок
# ✅ q073_2 — преобразуется в float без ошибок
# ✅ q074_0 — преобразуется в float без ошибок
# ✅ q074_1 — преобразуется в float без ошибок
# ✅ q075_0 — преобразуется в float без ошибок
# ✅ q075_1 — преобразуется в float без ошибок
# ✅ q077_001_1 — преобразуется в float без ошибок
# ✅ q077_002_1 — преобразуется в float без ошибок
# ✅ q077_003_1 — преобразуется в float без ошибок
# ✅ q077_004_1 — преобразуется в float без ошибок
# ✅ q077_005_1 — преобразуется в float без ошибок
# ✅ q077_006_1 — преобразуется в float без ошибок
# ✅ q077_007_1 — преобразуется в float без ошибок
# ✅ q077_008_1 — преобразуется в float без ошибок
# ✅ q077_009_1 — преобразуется в float без ошибок
# ✅ q093_001_1 — преобразуется в float без ошибок
# ✅ q093_002_1 — преобразуется в float без ошибок
# ✅ q093_003_1 — преобразуется в float без ошибок
# ✅ q093_004_1 — преобразуется в float без ошибок
# ✅ q093_005_1 — преобразуется в float без ошибок
# ✅ q093_006_1 — преобразуется в float без ошибок
# ✅ q093_007_1 — преобразуется в float без ошибок
# ✅ q093_008_1 — преобразуется в float без ошибок
# ✅ q093_009_1 — преобразуется в float без ошибок
# ✅ q097_001_1 — преобразуется в float без ошибок
# ✅ q097_002_1 — преобразуется в float без ошибок
# ✅ q097_003_1 — преобразуется в float без ошибок
# ✅ q097_004_1 — преобразуется в float без ошибок
# ✅ q097_005_1 — преобразуется в float без ошибок
# ✅ q097_006_1 — преобразуется в float без ошибок
# ✅ q097_007_1 — преобразуется в float без ошибок
# ✅ q097_89_1 — преобразуется в float без ошибок
# ✅ q097_010_1 — преобразуется в float без ошибок
# ✅ q097_008_1 — преобразуется в float без ошибок
# ✅ q097_009_1 — преобразуется в float без ошибок
# ✅ q099_001_1 — преобразуется в float без ошибок
# ✅ q099_002_1 — преобразуется в float без ошибок
# ✅ q099_003_1 — преобразуется в float без ошибок
# ✅ q099_004_1 — преобразуется в float без ошибок
# ✅ q099_005_1 — преобразуется в float без ошибок
# ✅ q099_006_1 — преобразуется в float без ошибок
# ✅ q099_007_1 — преобразуется в float без ошибок
# ✅ q099_008_1 — преобразуется в float без ошибок
# ✅ q099_009_1 — преобразуется в float без ошибок
# ✅ q109_001_0 — преобразуется в float без ошибок
# ✅ q109_001_1 — преобразуется в float без ошибок
# ✅ q109_001_2 — преобразуется в float без ошибок
# ✅ q109_002_0 — преобразуется в float без ошибок
# ✅ q109_002_1 — преобразуется в float без ошибок
# ✅ q109_002_2 — преобразуется в float без ошибок
# ✅ q109_003_0 — преобразуется в float без ошибок
# ✅ q109_003_1 — преобразуется в float без ошибок
# ✅ q109_003_2 — преобразуется в float без ошибок
# ✅ q109_004_0 — преобразуется в float без ошибок
# ✅ q109_004_1 — преобразуется в float без ошибок
# ✅ q109_004_2 — преобразуется в float без ошибок
# ✅ q109_005_0 — преобразуется в float без ошибок
# ✅ q109_005_1 — преобразуется в float без ошибок
# ✅ q109_005_2 — преобразуется в float без ошибок
# ✅ q109_006_0 — преобразуется в float без ошибок
# ✅ q109_006_1 — преобразуется в float без ошибок
# ✅ q109_006_2 — преобразуется в float без ошибок
# ✅ q109_007_0 — преобразуется в float без ошибок
# ✅ q109_007_1 — преобразуется в float без ошибок
# ✅ q109_007_2 — преобразуется в float без ошибок
# ✅ q109_008_0 — преобразуется в float без ошибок
# ✅ q109_008_1 — преобразуется в float без ошибок
# ✅ q109_008_2 — преобразуется в float без ошибок
# ✅ q109_009_0 — преобразуется в float без ошибок
# ✅ q109_009_1 — преобразуется в float без ошибок
# ✅ q109_009_2 — преобразуется в float без ошибок
# ✅ q137_001_0 — преобразуется в float без ошибок
# ✅ q137_001_1 — преобразуется в float без ошибок
# ✅ q137_002_0 — преобразуется в float без ошибок
# ✅ q137_002_1 — преобразуется в float без ошибок
# ✅ q137_003_0 — преобразуется в float без ошибок
# ✅ q137_003_1 — преобразуется в float без ошибок
# ✅ q137_004_0 — преобразуется в float без ошибок
# ✅ q137_004_1 — преобразуется в float без ошибок
# ✅ q137_005_0 — преобразуется в float без ошибок
# ✅ q137_005_1 — преобразуется в float без ошибок
# ✅ q137_006_0 — преобразуется в float без ошибок
# ✅ q137_006_1 — преобразуется в float без ошибок
# ✅ q137_007_0 — преобразуется в float без ошибок
# ✅ q137_007_1 — преобразуется в float без ошибок
# ✅ q137_008_0 — преобразуется в float без ошибок
# ✅ q137_008_1 — преобразуется в float без ошибок
# ✅ q137_009_0 — преобразуется в float без ошибок
# ✅ q137_009_1 — преобразуется в float без ошибок
# ✅ q137_010_0 — преобразуется в float без ошибок
# ✅ q137_010_1 — преобразуется в float без ошибок
# ✅ q137_011_0 — преобразуется в float без ошибок
# ✅ q137_011_1 — преобразуется в float без ошибок
# ✅ q137_012_0 — преобразуется в float без ошибок
# ✅ q137_012_1 — преобразуется в float без ошибок
# ✅ q137_013_0 — преобразуется в float без ошибок
# ✅ q137_013_1 — преобразуется в float без ошибок
# ✅ q137_014_0 — преобразуется в float без ошибок
# ✅ q137_014_1 — преобразуется в float без ошибок
# ✅ q137_015_0 — преобразуется в float без ошибок
# ✅ q137_015_1 — преобразуется в float без ошибок
# ✅ q137_016_0 — преобразуется в float без ошибок
# ✅ q137_016_1 — преобразуется в float без ошибок
# ✅ q137_017_0 — преобразуется в float без ошибок
# ✅ q137_017_1 — преобразуется в float без ошибок
# ✅ q137_018_0 — преобразуется в float без ошибок
# ✅ q137_018_1 — преобразуется в float без ошибок

# %%
# Автоматическая фильрация переменных. Удаление незначимых признаков
lasso = LassoCV(cv=10).fit(X_data, y)
selected_features = X_data.columns[lasso.coef_ != 0]
print("Отобранные Lasso признаки:", selected_features)
# Out:
# Отобранные Lasso признаки: Index(['q004', 'q021', 'q022_002', 'q022_003', 'q022_004', 'q022_005',
#        'q023_001', 'q023_002', 'q023_003', 'q025_003',
#        ...
#        'q073_1', 'q097_008_1', 'q099_007_1', 'q109_005_1', 'q137_003_0',
#        'q137_004_1', 'q137_007_1', 'q137_010_0', 'q137_015_1', 'q137_017_1'],
#       dtype='object', length=126)

# %%
len(selected_features.to_list())
# Out:
# 126

# %%
# Удаление незначимых признаков
selected = selected_features.to_list()

for var in selected:
    if pd.api.types.is_bool_dtype(df_no_methods_wo_open_encoded_clean[var]): 
        df_no_methods_wo_open_encoded_clean[var] = df_no_methods_wo_open_encoded_clean[var].astype('float64')


y = df_no_methods_wo_open_encoded_clean['SLEEP']
X = df_no_methods_wo_open_encoded_clean[selected]  # Признаки

X = sm.add_constant(X)

model = sm.OLS(y, X)  # y — зависимая переменная, X — признаки + константа
results = model.fit()  # Обучение модели

# %%
# Отбор значимых переменных

p_values = results.pvalues
significant_features = p_values[p_values < 0.05].index.tolist()
len(significant_features)
# Out:
# 31

# %% [markdown]
# ## Факторный анализ

# %% [markdown]
# ### Подбор количества факторов

# %%
df_factor = df_no_methods_wo_open_encoded_clean[significant_features]

# %%
kmo_all, kmo_model = calculate_kmo(df_factor)
kmo_model
# Out:
# C:\Users\79118\anaconda3\Lib\site-packages\factor_analyzer\utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(
# 0.8185538026593812

# %%
chi_square_value, p_value = calculate_bartlett_sphericity(df_factor)
chi_square_value, p_value
# Out:
# (11217.503107875353, 0.0)

# %%
fa = FactorAnalyzer()
fa.fit(df_factor)
ev, v = fa.get_eigenvalues()
ev
# Out:
# array([4.73681302, 2.09950599, 1.57620249, 1.49351815, 1.33146764,
#        1.2021254 , 1.17187857, 1.10592387, 1.06061704, 1.05858077,
#        0.99949937, 0.96594945, 0.93652574, 0.92517489, 0.87197768,
#        0.81370133, 0.7987947 , 0.75375498, 0.72823894, 0.70168217,
#        0.67463462, 0.63233096, 0.62069237, 0.58913429, 0.58190897,
#        0.55027202, 0.53955926, 0.5195924 , 0.38335578, 0.2939707 ,
#        0.28261643])

# %%
len(ev[ev > 1])
# Out:
# 10

# %%
# Функция для Parallel Analysis
def parallel_analysis(data, n_iter=100, method='ml'):
    # Реальный анализ
    fa = FactorAnalyzer(method=method, use_smc=True)
    fa.fit(data)
    real_eigenvalues = fa.get_eigenvalues()[0]

    # Случайные данные
    random_eigenvalues = []
    cov_matrix = np.cov(data, rowvar=False)
    for _ in range(n_iter):
        random_data = np.random.multivariate_normal(
            mean=np.zeros(data.shape[1]), 
            cov=cov_matrix, 
            size=data.shape[0]
        )
        fa.fit(random_data)
        random_eigenvalues.append(fa.get_eigenvalues()[0])

    # Критические значения (95-й процентиль)
    crit_eigenvalues = np.percentile(random_eigenvalues, 95, axis=0)

    # Сравнение
    n_factors = sum(real_eigenvalues > crit_eigenvalues)
    return n_factors, real_eigenvalues, crit_eigenvalues

# Запуск
n_factors, real_eigen, crit_eigen = parallel_analysis(df_factor)
print(f"Рекомендуемое число факторов: {n_factors}")
# Out:
# Рекомендуемое число факторов: 4

# %%
fa = FactorAnalyzer()
fa.set_params(n_factors=4, rotation='varimax', method='ml', use_smc=True)
fa.fit(df_factor)
loadings = fa.loadings_

# %%
explained_variance = fa.get_factor_variance()[1]  # Доля дисперсии для каждого фактора
total_variance = explained_variance.sum()  # Общая объясненная дисперсия
print("Доля дисперсии по факторам:", explained_variance)
print("Общая объясненная дисперсия (%):", total_variance * 100)
# Out:
# Доля дисперсии по факторам: [0.10340961 0.06705162 0.03230483 0.02993653]
# Общая объясненная дисперсия (%): 23.270259044367858

# %%
factor_scores = fa.transform(df_factor)

factor_scores_df = pd.DataFrame(
    factor_scores,
    columns=[f"Factor_{i+1}" for i in range(fa.n_factors)]
)

# %% [markdown]
# ### Проверка предсказательных качеств переменных

# %%
# Подготовка данных
X2 = factor_scores_df  # Факторы
y2 =  df_no_methods_wo_open_encoded_clean["SLEEP"]  # Целевая переменная

X2 = sm.add_constant(X2)

model2 = sm.OLS(y2, X2)  # y — зависимая переменная, X — признаки + константа
results2 = model2.fit()  # Обучение модели

# %%
print(results2.summary(results2))
# Out:
#                                                                  OLS Regression Results
# =======================================================================================================================================================
# Dep. Variable:     <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000024B843B3FB0>   R-squared:                       0.420
# Model:                                                                                                     OLS   Adj. R-squared:                  0.418
# Method:                                                                                          Least Squares   F-statistic:                     375.5
# Date:                                                                                         Sun, 25 May 2025   Prob (F-statistic):          1.63e-243
# Time:                                                                                                 23:33:20   Log-Likelihood:                -4957.9
# No. Observations:                                                                                         2083   AIC:                             9926.
# Df Residuals:                                                                                             2078   BIC:                             9954.
# Df Model:                                                                                                    4
# Covariance Type:                                                                                     nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.3970      0.057    111.518      0.000       6.285       6.510
# Factor_1       1.9099      0.065     29.177      0.000       1.782       2.038
# Factor_2       0.7063      0.064     11.101      0.000       0.582       0.831
# Factor_3       0.2114      0.076      2.781      0.005       0.062       0.361
# Factor_4       1.1540      0.072     16.023      0.000       1.013       1.295
# ==============================================================================
# Omnibus:                       15.019   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.275
# Skew:                           0.205   Prob(JB):                     0.000482
# Kurtosis:                       2.915   Cond. No.                         1.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
significant_features_tb = pd.DataFrame({'sign': significant_features})

# %%
df_fa = pd.DataFrame(loadings).reset_index()

cols = [f'Factor{x}' for x in range(1, 5)]
cols.insert(0, '№')
cols_all = cols.copy()
cols_all.insert(1, 'sign')


df_fa.columns = cols
df_fa = (df_fa.merge(significant_features_tb['sign'], how='left', left_index=True, right_index=True)
         .reindex(columns=cols_all))
df_fa.round(2)
# Out:
#      №        sign  Factor1  Factor2  Factor3  Factor4
# 0    0        q021     0.19     0.50     0.02    -0.05
# 1    1    q022_004     0.11     0.83    -0.08     0.01
# 2    2    q022_005     0.07     0.83    -0.05     0.01
# 3    3    q025_006     0.18     0.32     0.01     0.01
# 4    4    q031_005    -0.46    -0.16     0.30     0.08
# 5    5    q031_006    -0.48    -0.28    -0.02     0.14
# 6    6    q031_008    -0.58    -0.15     0.13     0.04
# 7    7        q042     0.21    -0.00     0.11     0.04
# 8    8        q043     0.07     0.08    -0.02     0.03
# 9    9        q044     0.42     0.08     0.19     0.04
# 10  10    q059_003    -0.08    -0.11     0.26     0.05
# 11  11        q078     0.29    -0.00     0.52    -0.10
# 12  12        q089     0.29     0.03     0.46    -0.05
# 13  13        q112     0.48     0.16     0.06     0.13
# 14  14        q119     0.55     0.16     0.06     0.64
# 15  15        q120     0.52     0.14     0.09     0.59
# 16  16    q139_005    -0.27    -0.16     0.35     0.03
# 17  17    q139_007     0.31     0.07    -0.02     0.02
# 18  18     q141_01     0.16     0.03     0.04    -0.04
# 19  19       PHQ_9     0.73     0.21    -0.01     0.24
# 20  20         RES    -0.55    -0.14     0.07    -0.15
# 21  21      q132_1    -0.10     0.02    -0.17     0.00
# 22  22      q145_3     0.01     0.05    -0.03    -0.10
# 23  23  q035_010_0    -0.18    -0.13     0.16     0.08
# 24  24  q051_003_1     0.23     0.06     0.01     0.01
# 25  25  q056_004_0    -0.06    -0.12     0.05     0.07
# 26  26  q064_006_2    -0.00    -0.01    -0.03    -0.01
# 27  27  q064_007_0     0.01    -0.01     0.12     0.01
# 28  28  q099_007_1    -0.14    -0.08    -0.08     0.01
# 29  29  q109_005_1     0.04     0.00    -0.05     0.00
# 30  30  q137_003_0     0.03     0.04    -0.24    -0.06

# %%
df_fa_pivot = (df_fa.pivot_table(index='sign')
               .sort_values(by=['№']).drop(columns=['№']))
plt.figure(figsize=(13, 13))
sns.heatmap(df_fa_pivot, annot=True, fmt='.1%', linewidths=1, linecolor='gray');

# %%
df_no_methods_wo_open_comp = fillna_custom(df_no_methods_wo_open, df_no_methods_wo_open.columns)

# %%
df_no_methods_wo_open_comp
# Out:
#       q002  q003  q004  q005  q006  q007  q008  q009  q010  q011  ...  SLEEP  \
# 0      1.0   1.0  18.0   1.0   1.0   0.0   4.0   0.0   0.0  -1.0  ...   12.0
# 1      0.0   0.0  20.0   3.0   1.0   0.0   4.0   0.0   0.0  -1.0  ...    6.0
# 2      1.0  -1.0  19.0   1.0   1.0   0.0   4.0   0.0   2.0  -1.0  ...    7.0
# 3      0.0   0.0  19.0   1.0   1.0   0.0   3.0   3.0   0.0  -1.0  ...    6.0
# 4      1.0   0.0  24.0   3.0   1.0   0.0   3.0   0.0   0.0  -1.0  ...   13.0
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...    ...
# 2078   0.0   0.0  19.0   1.0   1.0   0.0   4.0   7.0   5.0  -1.0  ...    9.0
# 2079   0.0   0.0  19.0   1.0   1.0   0.0   4.0   7.0   0.0  -1.0  ...    5.0
# 2080   2.0   0.0  23.0   4.0   1.0   1.0   4.0   7.0   2.0  -1.0  ...    5.0
# 2081   1.0   1.0  22.0   1.0   1.0   0.0   3.0   7.0   6.0  -1.0  ...   12.0
# 2082   2.0   0.0  26.0   1.0   1.0   0.0   4.0   0.0   6.0  -1.0  ...    4.0
#
#       OSSS  OSSScat  STRESS  STRESScat  alko  AUDIT   SF  Ind  \
# 0      8.0      0.0     7.0        0.0   2.0   -1.0 -1.0  1.0
# 1     12.0      1.0    10.0       -1.0   2.0    0.0  0.0  0.0
# 2      9.0      2.0    10.0        2.0   3.0   -1.0  3.0  1.0
# 3     11.0      2.0    11.0        2.0   2.0    0.0  1.0  1.0
# 4     10.0      2.0    11.0        2.0   0.0    0.0 -1.0  1.0
# ...    ...      ...     ...        ...   ...    ...  ...  ...
# 2078   8.0      0.0     7.0        0.0   2.0   -1.0  0.0  1.0
# 2079   8.0      0.0    10.0        2.0   2.0   -1.0  3.0  0.0
# 2080   7.0      0.0    12.0        2.0   3.0    1.0  2.0  0.0
# 2081   8.0      0.0     6.0        0.0   2.0    0.0  3.0  1.0
# 2082   8.0      0.0     8.0        0.0   2.0   -1.0  1.0  0.0
#
#       average_time_sleep_dur
# 0                        7.0
# 1                        7.0
# 2                        6.5
# 3                        7.0
# 4                        7.5
# ...                      ...
# 2078                     6.0
# 2079                     5.5
# 2080                     7.0
# 2081                     4.0
# 2082                     8.0
#
# [2083 rows x 390 columns]

# %%
threshold = 0.5 * len(df_no_methods_wo_open)  # 50% от размера выборки

# Вычисление количества пропусков в каждом столбце
missing_counts = df_no_methods_wo_open.isnull().sum()
columns_to_drop = missing_counts[missing_counts > threshold].index

print(columns_to_drop)
df_no_methods_wo_open_comp = df_no_methods_wo_open.drop(columns=columns_to_drop)


missing_in_clean = df_no_methods_wo_open_comp.isnull().sum()
missing_in_clean_only = missing_in_clean[missing_in_clean > 0]

columns_to_fill = missing_in_clean_only.index
df_no_methods_wo_open_comp_clean = fillna_custom(df_no_methods_wo_open_comp, columns_to_fill)
# Out:
# Index([], dtype='object')

# %%
df_cyber = df_no_methods_wo_open_comp_clean[df_no_methods_wo_open_comp_clean['q126'] == 1]
df_not = df_no_methods_wo_open_comp_clean[df_no_methods_wo_open_comp_clean['q126'] == 2]

# %%
for l in num_comp:
    print(f'check l = {l}')
    u_c = U(df_cyber[l], df_not[l])
    if u_c.pvalue < 0.05:
        mean_cy, mean_not = df_cyber[l].mean(), df_not[l].mean()
        print(f'U-критерий равен: {u_c}')
        print(f'Средние значения данных групп равны: {mean_cy} (используют), {mean_not} (нет)')
# Out:
# check l = q012
# check l = q021
# check l = q022_001
# check l = q022_002
# U-критерий равен: MannwhitneyuResult(statistic=521730.5, pvalue=0.03725082652065028)
# Средние значения данных групп равны: 1.8037889039242219 (используют), 1.7194940476190477 (нет)
# check l = q022_003
# check l = q022_004
# check l = q022_005
# check l = q023_001
# U-критерий равен: MannwhitneyuResult(statistic=463720.5, pvalue=0.008458634965285147)
# Средние значения данных групп равны: 3.810554803788904 (используют), 3.9404761904761907 (нет)
# check l = q023_002
# check l = q023_003
# U-критерий равен: MannwhitneyuResult(statistic=569785.5, pvalue=1.0745691074526553e-08)
# Средние значения данных групп равны: 2.9336941813261164 (используют), 2.5632440476190474 (нет)
# check l = q023_004
# check l = q025_001
# check l = q025_002
# check l = q025_003
# U-критерий равен: MannwhitneyuResult(statistic=465323.5, pvalue=0.012938600116421756)
# Средние значения данных групп равны: 2.7036535859269284 (используют), 2.8132440476190474 (нет)
# check l = q025_004
# U-критерий равен: MannwhitneyuResult(statistic=530913.5, pvalue=0.005842088237284242)
# Средние значения данных групп равны: 2.246278755074425 (используют), 2.1220238095238093 (нет)
# check l = q025_005
# check l = q025_006
# check l = q025_007
# check l = q030_001
# U-критерий равен: MannwhitneyuResult(statistic=450242.5, pvalue=0.0003053512817485336)
# Средние значения данных групп равны: 4.162381596752368 (используют), 4.386904761904762 (нет)
# check l = q030_002
# check l = q030_003
# U-критерий равен: MannwhitneyuResult(statistic=444623.5, pvalue=5.5376617936855954e-05)
# Средние значения данных групп равны: 4.309878213802436 (используют), 4.584821428571429 (нет)
# check l = q030_004
# U-критерий равен: MannwhitneyuResult(statistic=432949.5, pvalue=9.371817506712041e-07)
# Средние значения данных групп равны: 4.040595399188092 (используют), 4.450148809523809 (нет)
# check l = q031_001
# U-критерий равен: MannwhitneyuResult(statistic=439952.0, pvalue=1.5321282738944266e-06)
# Средние значения данных групп равны: 3.6211096075778078 (используют), 3.8050595238095237 (нет)
# check l = q031_002
# check l = q031_003
# check l = q031_004
# U-критерий равен: MannwhitneyuResult(statistic=463759.0, pvalue=0.006851398990830139)
# Средние значения данных групп равны: 3.8443843031123137 (используют), 3.9583333333333335 (нет)
# check l = q031_005
# U-критерий равен: MannwhitneyuResult(statistic=465614.5, pvalue=0.011160315433409649)
# Средние значения данных групп равны: 4.0 (используют), 4.116071428571429 (нет)
# check l = q031_006
# U-критерий равен: MannwhitneyuResult(statistic=442465.5, pvalue=1.8662515165645784e-05)
# Средние значения данных групп равны: 3.1637347767253043 (используют), 3.3913690476190474 (нет)
# check l = q031_007
# U-критерий равен: MannwhitneyuResult(statistic=436738.5, pvalue=1.9211782063818343e-06)
# Средние значения данных групп равны: 3.194857916102842 (используют), 3.4456845238095237 (нет)
# check l = q031_008
# U-критерий равен: MannwhitneyuResult(statistic=438586.0, pvalue=3.379649047259757e-06)
# Средние значения данных групп равны: 3.3991880920162383 (используют), 3.6510416666666665 (нет)
# check l = q031_009
# U-критерий равен: MannwhitneyuResult(statistic=434834.0, pvalue=7.165950478489015e-07)
# Средние значения данных групп равны: 3.503382949932341 (используют), 3.7373511904761907 (нет)
# check l = q031_010
# U-критерий равен: MannwhitneyuResult(statistic=454614.0, pvalue=0.0005410633741098284)
# Средние значения данных групп равны: 3.9269282814614344 (используют), 4.086309523809524 (нет)
# check l = q031_011
# U-критерий равен: MannwhitneyuResult(statistic=412346.5, pvalue=3.4206000329391316e-11)
# Средние значения данных групп равны: 2.814614343707713 (используют), 3.168154761904762 (нет)
# check l = q038
# U-критерий равен: MannwhitneyuResult(statistic=423065.5, pvalue=4.870389489771713e-09)
# Средние значения данных групп равны: 2.691474966170501 (используют), 2.9635416666666665 (нет)
# check l = q041
# U-критерий равен: MannwhitneyuResult(statistic=557317.0, pvalue=9.766620406933882e-07)
# Средние значения данных групп равны: 2.8646820027063598 (используют), 2.640625 (нет)
# check l = q042
# U-критерий равен: MannwhitneyuResult(statistic=538307.5, pvalue=0.0007810730704912804)
# Средние значения данных групп равны: 2.208389715832206 (используют), 2.034970238095238 (нет)
# check l = q043
# U-критерий равен: MannwhitneyuResult(statistic=508875.0, pvalue=0.047114310522165574)
# Средние значения данных групп равны: 1.1028416779431665 (используют), 1.0758928571428572 (нет)
# check l = q044
# U-критерий равен: MannwhitneyuResult(statistic=578975.0, pvalue=1.0530486635041491e-10)
# Средние значения данных групп равны: 2.8579161028416777 (используют), 2.4791666666666665 (нет)
# check l = q046_001
# check l = q046_002
# check l = q052
# check l = q057_001
# check l = q057_002
# check l = q057_003
# U-критерий равен: MannwhitneyuResult(statistic=455874.5, pvalue=0.00018378120736974266)
# Средние значения данных групп равны: 1.591339648173207 (используют), 1.6733630952380953 (нет)
# check l = q057_004
# check l = q057_005
# U-критерий равен: MannwhitneyuResult(statistic=473105.5, pvalue=0.031714011712281505)
# Средние значения данных групп равны: 1.3328822733423544 (используют), 1.3802083333333333 (нет)
# check l = q057_006
# check l = q057_007
# check l = q057_89
# U-критерий равен: MannwhitneyuResult(statistic=455974.0, pvalue=0.00020760377593174805)
# Средние значения данных групп равны: 1.5818673883626522 (используют), 1.6636904761904763 (нет)
# check l = q057_010
# check l = q057_011
# check l = q057_012
# U-критерий равен: MannwhitneyuResult(statistic=477061.5, pvalue=0.03145903426389962)
# Средние значения данных групп равны: 1.7753721244925575 (используют), 1.8147321428571428 (нет)
# check l = q057_013
# check l = q057_014
# U-критерий равен: MannwhitneyuResult(statistic=470183.0, pvalue=0.0006359154219080907)
# Средние значения данных групп равны: 1.8322056833558864 (используют), 1.8854166666666667 (нет)
# check l = q057_008
# U-критерий равен: MannwhitneyuResult(statistic=472351.5, pvalue=0.013448239749218965)
# Средние значения данных групп равны: 1.7212449255751014 (используют), 1.7700892857142858 (нет)
# check l = q057_009
# U-критерий равен: MannwhitneyuResult(statistic=466744.0, pvalue=0.0016314610902154582)
# Средние значения данных групп равны: 1.7374830852503382 (используют), 1.7976190476190477 (нет)
# check l = q057_015
# check l = q059_001
# check l = q059_002
# check l = q059_003
# check l = q059_004
# U-критерий равен: MannwhitneyuResult(statistic=533333.5, pvalue=0.003851236758071298)
# Средние значения данных групп равны: 2.543978349120433 (используют), 2.371279761904762 (нет)
# check l = q059_005
# check l = q059_006
# check l = q059_007
# check l = q059_008
# check l = q059_009
# U-критерий равен: MannwhitneyuResult(statistic=473150.0, pvalue=0.018405200676349175)
# Средние значения данных групп равны: 4.565629228687415 (используют), 4.640625 (нет)
# check l = q059_010
# check l = q061
# check l = q062_001
# check l = q063_001
# check l = q063_002
# check l = q063_003
# check l = q063_004
# check l = q063_005
# check l = q063_006
# check l = q063_007
# check l = q067_001
# U-критерий равен: MannwhitneyuResult(statistic=480803.5, pvalue=0.04804649951870218)
# Средние значения данных групп равны: 4.588633288227334 (используют), 4.666666666666667 (нет)
# check l = q067_002
# U-критерий равен: MannwhitneyuResult(statistic=491304.0, pvalue=0.016812203554036197)
# Средние значения данных групп равны: 1.0081190798376185 (используют), 1.0357142857142858 (нет)
# check l = q067_003
# U-критерий равен: MannwhitneyuResult(statistic=509349.0, pvalue=0.021586941702100973)
# Средние значения данных групп равны: 1.2422192151556157 (используют), 1.1569940476190477 (нет)
# check l = q067_004
# check l = q067_005
# check l = q067_006
# check l = q067_007
# check l = q067_008
# check l = q067_009
# check l = q067_010
# check l = q078
# U-критерий равен: MannwhitneyuResult(statistic=536345.5, pvalue=0.00026277217607725844)
# Средние значения данных групп равны: 2.6427604871447903 (используют), 2.5245535714285716 (нет)
# check l = q080
# U-критерий равен: MannwhitneyuResult(statistic=452413.0, pvalue=3.9273790258580825e-05)
# Средние значения данных групп равны: 4.534506089309878 (используют), 4.659226190476191 (нет)
# check l = q088_001
# U-критерий равен: MannwhitneyuResult(statistic=503543.5, pvalue=0.03803521873121798)
# Средние значения данных групп равны: 1.0351826792963463 (используют), 1.0208333333333333 (нет)
# check l = q088_002
# U-критерий равен: MannwhitneyuResult(statistic=522960.5, pvalue=0.00033945328951062856)
# Средние значения данных групп равны: 1.2557510148849798 (используют), 1.1517857142857142 (нет)
# check l = q088_003
# U-критерий равен: MannwhitneyuResult(statistic=516248.5, pvalue=0.00011377017174270634)
# Средние значения данных групп равны: 1.1096075778078485 (используют), 1.0625 (нет)
# check l = q088_004
# check l = q088_005
# check l = q088_006
# check l = q088_007
# check l = q089
# U-критерий равен: MannwhitneyuResult(statistic=568624.5, pvalue=1.2065557645712531e-09)
# Средние значения данных групп равны: 2.472259810554804 (используют), 2.2447916666666665 (нет)
# check l = q091
# U-критерий равен: MannwhitneyuResult(statistic=432844.0, pvalue=2.0717754951948346e-07)
# Средние значения данных групп равны: 4.680649526387009 (используют), 4.991815476190476 (нет)
# check l = q092
# U-критерий равен: MannwhitneyuResult(statistic=471501.0, pvalue=0.0010352837720017344)
# Средние значения данных групп равны: 5.7550744248985115 (используют), 5.850446428571429 (нет)
# check l = q094
# U-критерий равен: MannwhitneyuResult(statistic=555804.0, pvalue=1.9314980965200748e-07)
# Средние значения данных групп равны: 1.5656292286874154 (используют), 1.4464285714285714 (нет)
# check l = q095_001
# check l = q095_002
# check l = q095_003
# U-критерий равен: MannwhitneyuResult(statistic=521217.0, pvalue=0.0026024278907701235)
# Средние значения данных групп равны: 1.6684709066305818 (используют), 1.4694940476190477 (нет)
# check l = q095_004
# check l = q095_005
# check l = q095_006
# check l = q095_007
# check l = q095_008
# check l = q095_009
# check l = q098
# check l = q106_001
# check l = q106_002
# check l = q106_003
# check l = q106_004
# check l = q106_005
# check l = q106_006
# check l = q106_007
# check l = q107_001
# U-критерий равен: MannwhitneyuResult(statistic=550329.0, pvalue=2.7613935946746973e-05)
# Средние значения данных групп равны: 3.50744248985115 (используют), 3.2388392857142856 (нет)
# check l = q107_002
# U-критерий равен: MannwhitneyuResult(statistic=537084.5, pvalue=0.0011630830661753036)
# Средние значения данных групп равны: 2.2516914749661705 (используют), 2.072172619047619 (нет)
# check l = q107_003
# U-критерий равен: MannwhitneyuResult(statistic=538536.0, pvalue=0.0010876469605758138)
# Средние значения данных групп равны: 2.986468200270636 (используют), 2.7782738095238093 (нет)
# check l = q107_004
# check l = q107_005
# U-критерий равен: MannwhitneyuResult(statistic=553169.5, pvalue=6.594198150180362e-06)
# Средние значения данных групп равны: 2.331529093369418 (используют), 2.081845238095238 (нет)
# check l = q107_006
# U-критерий равен: MannwhitneyuResult(statistic=554451.5, pvalue=4.715754828972015e-06)
# Средние значения данных групп равны: 2.4709066305818674 (используют), 2.2061011904761907 (нет)
# check l = q107_007
# U-критерий равен: MannwhitneyuResult(statistic=532976.0, pvalue=8.44507811901042e-05)
# Средние значения данных групп равны: 1.3288227334235454 (используют), 1.2447916666666667 (нет)
# check l = q108_001
# U-критерий равен: MannwhitneyuResult(statistic=538649.0, pvalue=0.0008319456622799748)
# Средние значения данных групп равны: 3.807848443843031 (используют), 3.6264880952380953 (нет)
# check l = q108_002
# U-критерий равен: MannwhitneyuResult(statistic=535828.5, pvalue=0.00198429428979119)
# Средние значения данных групп равны: 2.894451962110961 (используют), 2.732142857142857 (нет)
# check l = q108_003
# U-критерий равен: MannwhitneyuResult(statistic=543164.5, pvalue=0.00024822530171561086)
# Средние значения данных групп равны: 3.6941813261163734 (используют), 3.486607142857143 (нет)
# check l = q108_004
# U-критерий равен: MannwhitneyuResult(statistic=526323.5, pvalue=0.0038599693003403897)
# Средние значения данных групп равны: 1.3964817320703653 (используют), 1.3169642857142858 (нет)
# check l = q108_005
# U-критерий равен: MannwhitneyuResult(statistic=547593.0, pvalue=5.2954555356858084e-05)
# Средние значения данных групп равны: 3.1163734776725303 (используют), 2.9285714285714284 (нет)
# check l = q108_006
# U-критерий равен: MannwhitneyuResult(statistic=551505.5, pvalue=1.6592172230523937e-05)
# Средние значения данных групп равны: 3.147496617050068 (используют), 2.918154761904762 (нет)
# check l = q108_007
# U-критерий равен: MannwhitneyuResult(statistic=538979.5, pvalue=0.000400257661747537)
# Средние значения данных групп равны: 1.7916102841677943 (используют), 1.6517857142857142 (нет)
# check l = q112
# U-критерий равен: MannwhitneyuResult(statistic=587933.0, pvalue=1.7200264554147773e-13)
# Средние значения данных групп равны: 2.677943166441137 (используют), 2.380952380952381 (нет)
# check l = q119
# U-критерий равен: MannwhitneyuResult(statistic=556170.0, pvalue=1.6982135051505492e-06)
# Средние значения данных групп равны: 2.733423545331529 (используют), 2.5379464285714284 (нет)
# check l = q120
# U-критерий равен: MannwhitneyuResult(statistic=569859.5, pvalue=3.030859939193584e-09)
# Средние значения данных групп равны: 2.7510148849797025 (используют), 2.525297619047619 (нет)
# check l = q128
# U-критерий равен: MannwhitneyuResult(statistic=444846.0, pvalue=4.6212847095464544e-06)
# Средние значения данных групп равны: 2.9634641407307174 (используют), 3.1019345238095237 (нет)
# check l = q129
# U-критерий равен: MannwhitneyuResult(statistic=533352.0, pvalue=0.0029174674775107262)
# Средние значения данных групп равны: 2.4370771312584574 (используют), 2.3095238095238093 (нет)
# check l = q131_006
# U-критерий равен: MannwhitneyuResult(statistic=543823.0, pvalue=6.899413798332568e-05)
# Средние значения данных групп равны: 1.8064952638700946 (используют), 1.6837797619047619 (нет)
# check l = q131_007
# U-критерий равен: MannwhitneyuResult(statistic=469465.5, pvalue=0.026369023675230845)
# Средние значения данных групп равны: 2.108254397834912 (используют), 2.1808035714285716 (нет)
# check l = q131_008
# U-критерий равен: MannwhitneyuResult(statistic=468158.0, pvalue=0.021095173973376374)
# Средние значения данных групп равны: 1.9106901217861976 (используют), 1.9925595238095237 (нет)
# check l = q134_001
# check l = q134_002
# check l = q134_003
# check l = q134_004
# check l = q134_005
# U-критерий равен: MannwhitneyuResult(statistic=518577.0, pvalue=0.023210081465909072)
# Средние значения данных групп равны: 2.2043301759133964 (используют), 2.125 (нет)
# check l = q139_001
# check l = q139_002
# U-критерий равен: MannwhitneyuResult(statistic=436069.0, pvalue=2.0840733224260466e-06)
# Средние значения данных групп равны: 2.568335588633288 (используют), 2.8199404761904763 (нет)
# check l = q139_003
# U-критерий равен: MannwhitneyuResult(statistic=544197.0, pvalue=8.052120386128001e-05)
# Средние значения данных групп равны: 1.8538565629228687 (используют), 1.6830357142857142 (нет)
# check l = q139_004
# check l = q139_005
# check l = q139_006
# check l = q139_007
# U-критерий равен: MannwhitneyuResult(statistic=516093.0, pvalue=0.012283469264108284)
# Средние значения данных групп равны: 1.2760487144790258 (используют), 1.2083333333333333 (нет)
# check l = q139_008
# U-критерий равен: MannwhitneyuResult(statistic=525429.0, pvalue=0.022254975042675967)
# Средние значения данных групп равны: 3.0730717185385656 (используют), 2.9672619047619047 (нет)
# check l = q139_009
# U-критерий равен: MannwhitneyuResult(statistic=545537.0, pvalue=5.904456152660958e-05)
# Средние значения данных групп равны: 4.2408660351826795 (используют), 4.100446428571429 (нет)
# check l = q139_010
# U-критерий равен: MannwhitneyuResult(statistic=553044.0, pvalue=3.044042896377117e-07)
# Средние значения данных групп равны: 2.0866035182679297 (используют), 1.759672619047619 (нет)
# check l = q139_011
# U-критерий равен: MannwhitneyuResult(statistic=459276.5, pvalue=0.00288099661061154)
# Средние значения данных групп равны: 3.161028416779432 (используют), 3.2805059523809526 (нет)
# check l = q139_012
# U-критерий равен: MannwhitneyuResult(statistic=558852.0, pvalue=5.772436207908332e-07)
# Средние значения данных групп равны: 2.2895805142083896 (используют), 2.002232142857143 (нет)
# check l = q126
# U-критерий равен: MannwhitneyuResult(statistic=0.0, pvalue=0.0)
# Средние значения данных групп равны: 1.0 (используют), 2.0 (нет)
# check l = q135_001
# check l = q135_002
# check l = q135_003
# check l = q138

# %%
for l in other_cor:
    print(f'check l = {l}')
    u_c = U(df_cyber[l], df_not[l])
    if u_c.pvalue < 0.05:
        mean_cy, mean_not = df_cyber[l].mean(), df_not[l].mean()
        print(f'U-критерий равен: {u_c}')
        print(f'Средние значения данных групп равны: {mean_cy} (используют), {mean_not} (нет)')
# Out:
# check l = q004
# check l = q028
# check l = q040_001
# check l = q040_002
# check l = q040_003
# check l = q040_004
# U-критерий равен: MannwhitneyuResult(statistic=534885.5, pvalue=0.0003208391667535787)
# Средние значения данных групп равны: 2.5 (используют), 1.8865327380952381 (нет)
# check l = q079
# check l = q090
# check l = q096
# check l = q103
# check l = q118_01
# check l = q118_02
# check l = q133
# check l = PHQ_9
# U-критерий равен: MannwhitneyuResult(statistic=617367.5, pvalue=3.3761887030502164e-20)
# Средние значения данных групп равны: 11.077131258457374 (используют), 8.463541666666666 (нет)
# check l = RES
# U-критерий равен: MannwhitneyuResult(statistic=415441.5, pvalue=5.91228579454862e-10)
# Средние значения данных групп равны: 18.576454668470905 (используют), 19.913690476190474 (нет)
# check l = SAMEF
# U-критерий равен: MannwhitneyuResult(statistic=436177.0, pvalue=4.051368393404005e-06)
# Средние значения данных групп равны: 28.884979702300406 (используют), 30.25 (нет)
# check l = SLEEP
# U-критерий равен: MannwhitneyuResult(statistic=607116.0, pvalue=3.004950152260861e-17)
# Средние значения данных групп равны: 7.2516914749661705 (используют), 5.927083333333333 (нет)
# check l = OSSS
# U-критерий равен: MannwhitneyuResult(statistic=456635.0, pvalue=0.0020621621386376996)
# Средние значения данных групп равны: 9.143437077131258 (используют), 9.400297619047619 (нет)
# check l = STRESS
# check l = alko
# check l = AUDIT
# U-критерий равен: MannwhitneyuResult(statistic=528872.0, pvalue=0.008797360657344018)
# Средние значения данных групп равны: -0.06495263870094722 (используют), -0.15773809523809523 (нет)
# check l = Ind

# %%
df_cyber['q031_011'].mean(), df_not['q031_011'].mean()
# Out:
# (2.814614343707713, 3.163660165745082)
